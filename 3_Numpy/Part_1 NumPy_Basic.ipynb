# %%
# Syntax of Numpy
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
arr2 = np.array([5,4,3,2,1])
arrSum = arr + arr2
print(arrSum)
print(type(arrSum))
# Out:
# [6 6 6 6 6]
# <class 'numpy.ndarray'>
